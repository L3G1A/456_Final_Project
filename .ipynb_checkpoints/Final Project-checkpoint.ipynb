# %%
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
import cv2
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras import models, layers
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import Flatten
import matplotlib.pyplot as plt
from IPython.display import Image
from keras import metrics
from sklearn.metrics import confusion_matrix

# %%
root_path = "archive\\natural_images"

# %%
image_types = os.listdir(root_path)
print(image_types)
# Out:
# ['airplane', 'car', 'cat', 'dog', 'flower', 'fruit', 'motorbike', 'person']

# %%
X= []
Y = []

for image_type in image_types:
    type_folder = root_path + "\\" + image_type
    folder_data = os.listdir(type_folder)
    for image in folder_data:
        #opening image
        image_path = type_folder + "\\" + image
        image = cv2.imread(image_path)
        image_new = cv2.resize(image, (32,32))
        image_sized = image_new.astype("float32")/255
        X.append(np.array(image_sized))
        Y.append(image_type)

        
        image_flipped_hor = cv2.flip(image_new, 1)
        image_sized = image_flipped_hor.astype("float32")/255
        X.append(np.array(image_sized))
        Y.append(image_type)
        
        image_flipped_vert = cv2.flip(image_new, 1)
        image_sized = image_flipped_vert.astype("float32")/255
        X.append(np.array(image_sized))
        Y.append(image_type)

# %%
Y = np.array(Y)
X = np.array(X)

# %%
print('Example Images')
for image_type in image_types:
    type_folder = root_path + "\\" + image_type
    folder_data = os.listdir(type_folder)
    for image in folder_data:
        print(image_type , ":")
        image_path = type_folder + "\\" + image
        display(Image(filename=image_path))
        break
# Out:
# Example Images
# airplane :
# car :
# cat :
# dog :
# flower :
# fruit :
# motorbike :
# person :

# %%
enc = OneHotEncoder(sparse = False)
Y = enc.fit_transform(Y.reshape((-1,1)))

# %%
r = np.arange(X.shape[0])
np.random.seed(69)
np.random.shuffle(r)
X = X[r]
Y = Y[r]

# %%
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size = 0.33)
print(train_Y.shape)
print(train_X.shape)
# Out:
# (13866, 8)
# (13866, 32, 32, 3)

# %%
model = Sequential([
    BatchNormalization(input_shape=(32,32,3)),
    Conv2D(128, kernel_size=(5,5), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    Conv2D(32, kernel_size=(2,2), activation='relu'),
    Flatten(),
    Dense(256, activation = "relu"),
    Dense(128, activation = "sigmoid"),
    Dense(8, activation = "softmax")

])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_X, train_Y, batch_size=64, epochs=20,  validation_data=(test_X, test_Y))
# Out:
# Epoch 1/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.7320 - accuracy: 0.7412 - val_loss: 0.4568 - val_accuracy: 0.8308
# Epoch 2/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.3389 - accuracy: 0.8777 - val_loss: 0.3024 - val_accuracy: 0.8874
# Epoch 3/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.2491 - accuracy: 0.9064 - val_loss: 0.2834 - val_accuracy: 0.8942
# Epoch 4/20
# 217/217 [==============================] - 14s 66ms/step - loss: 0.1963 - accuracy: 0.9281 - val_loss: 0.2315 - val_accuracy: 0.9148
# Epoch 5/20
# 217/217 [==============================] - 14s 66ms/step - loss: 0.1425 - accuracy: 0.9480 - val_loss: 0.1802 - val_accuracy: 0.9371
# Epoch 6/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.1060 - accuracy: 0.9616 - val_loss: 0.1503 - val_accuracy: 0.9461
# Epoch 7/20
# 217/217 [==============================] - 14s 67ms/step - loss: 0.0801 - accuracy: 0.9724 - val_loss: 0.1509 - val_accuracy: 0.9463
# Epoch 8/20
# 217/217 [==============================] - 14s 67ms/step - loss: 0.0639 - accuracy: 0.9779 - val_loss: 0.1603 - val_accuracy: 0.9442
# Epoch 9/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.0430 - accuracy: 0.9859 - val_loss: 0.1571 - val_accuracy: 0.9483
# Epoch 10/20
# 217/217 [==============================] - 14s 67ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 0.1622 - val_accuracy: 0.9513
# Epoch 11/20
# 217/217 [==============================] - 14s 67ms/step - loss: 0.0458 - accuracy: 0.9834 - val_loss: 0.1949 - val_accuracy: 0.9435
# Epoch 12/20
# 217/217 [==============================] - 14s 67ms/step - loss: 0.0421 - accuracy: 0.9866 - val_loss: 0.1620 - val_accuracy: 0.9543
# Epoch 13/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.0279 - accuracy: 0.9911 - val_loss: 0.1774 - val_accuracy: 0.9510
# Epoch 14/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 0.1854 - val_accuracy: 0.9518
# Epoch 15/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.0201 - accuracy: 0.9939 - val_loss: 0.1714 - val_accuracy: 0.9546
# Epoch 16/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.1509 - val_accuracy: 0.9600
# Epoch 17/20
# 217/217 [==============================] - 14s 67ms/step - loss: 0.0186 - accuracy: 0.9936 - val_loss: 0.2023 - val_accuracy: 0.9447
# Epoch 18/20
# 217/217 [==============================] - 14s 66ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.1618 - val_accuracy: 0.9593
# Epoch 19/20
# 217/217 [==============================] - 14s 67ms/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.1982 - val_accuracy: 0.9479
# Epoch 20/20
# 217/217 [==============================] - 15s 67ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.1697 - val_accuracy: 0.9574

# %%
plt.plot(history.history['accuracy'], label='acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend(loc='lower right')

# %%
model = Sequential([
    BatchNormalization(input_shape=(32,32,3)),
    Conv2D(128, kernel_size=(5,5), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    Conv2D(32, kernel_size=(2,2), activation='relu'),
    Flatten(),
    Dense(256, activation = "relu"),
    Dense(128, activation = "sigmoid"),
    Dense(8, activation = "softmax")

])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_X, train_Y, batch_size=64, epochs=16,  validation_data=(test_X, test_Y))
# Out:
# Epoch 1/16
# 217/217 [==============================] - 15s 71ms/step - loss: 0.7577 - accuracy: 0.7284 - val_loss: 0.4137 - val_accuracy: 0.8574
# Epoch 2/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.3278 - accuracy: 0.8784 - val_loss: 0.2988 - val_accuracy: 0.8942
# Epoch 3/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.2386 - accuracy: 0.9109 - val_loss: 0.2377 - val_accuracy: 0.9108
# Epoch 4/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.1783 - accuracy: 0.9329 - val_loss: 0.2040 - val_accuracy: 0.9248
# Epoch 5/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.1364 - accuracy: 0.9503 - val_loss: 0.1877 - val_accuracy: 0.9290
# Epoch 6/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0945 - accuracy: 0.9665 - val_loss: 0.1847 - val_accuracy: 0.9372
# Epoch 7/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0699 - accuracy: 0.9758 - val_loss: 0.2093 - val_accuracy: 0.9319
# Epoch 8/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0559 - accuracy: 0.9813 - val_loss: 0.1758 - val_accuracy: 0.9435
# Epoch 9/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0581 - accuracy: 0.9802 - val_loss: 0.1522 - val_accuracy: 0.9507
# Epoch 10/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0309 - accuracy: 0.9900 - val_loss: 0.1585 - val_accuracy: 0.9539
# Epoch 11/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0237 - accuracy: 0.9931 - val_loss: 0.1574 - val_accuracy: 0.9559
# Epoch 12/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0339 - accuracy: 0.9877 - val_loss: 0.1777 - val_accuracy: 0.9480
# Epoch 13/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0356 - accuracy: 0.9891 - val_loss: 0.1677 - val_accuracy: 0.9505
# Epoch 14/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.1990 - val_accuracy: 0.9466
# Epoch 15/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0255 - accuracy: 0.9917 - val_loss: 0.1827 - val_accuracy: 0.9524
# Epoch 16/16
# 217/217 [==============================] - 15s 70ms/step - loss: 0.0250 - accuracy: 0.9919 - val_loss: 0.1810 - val_accuracy: 0.9554

# %%
print("Max Train Acccraucy: ", max(history.history['accuracy']))
print("Max Test Acccraucy: ", max(history.history['val_accuracy']))
# Out:
# Max Train Acccraucy:  0.9947353005409241
# Max Test Acccraucy:  0.9559361934661865

# %%
plt.plot(history.history['accuracy'], label='acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %%
predicted_Y = model.predict(test_X)
predicted_Y=np.argmax(predicted_Y, axis=1)
try:
    test_Y=np.argmax(test_Y, axis=1)
except:
    test_Y = test_Y
    
matrix = confusion_matrix(test_Y, predicted_Y)
fig, ax = plt.subplots(figsize=(6, 6))
ax.matshow(matrix, cmap=plt.cm.Reds, alpha=0.5)
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        ax.text(x=j, y=i,s=matrix[i, j], va='center', ha='center', size='large')
 
plt.xlabel('Predictioned Values', fontsize=15)
plt.ylabel('Actual Values', fontsize=15)
plt.title('Natrual Images Confusion Matrix', fontsize=20)
plt.show()

# %%
for i in range(0,20):
    print("Predicted: ", np.argmax(model.predict(np.array(test_X[[i],:,:]))))
    print("Result: ", np.argmax(test_Y[i]))
# Out:
# Predicted:  5
# Result:  0
# Predicted:  3
# Result:  0
# Predicted:  5
# Result:  0
# Predicted:  5
# Result:  0
# Predicted:  5
# Result:  0
# Predicted:  0
# Result:  0
# Predicted:  2
# Result:  0
# Predicted:  4
# Result:  0
# Predicted:  4
# Result:  0
# Predicted:  7
# Result:  0
# Predicted:  6
# Result:  0
# Predicted:  7
# Result:  0
# Predicted:  2
# Result:  0
# Predicted:  5
# Result:  0
# Predicted:  0
# Result:  0
# Predicted:  2
# Result:  0
# Predicted:  6
# Result:  0
# Predicted:  6
# Result:  0
# Predicted:  3
# Result:  0
# Predicted:  3
# Result:  0

# %%
X= []
Y = []

for image_type in image_types:
    type_folder = root_path + "\\" + image_type
    folder_data = os.listdir(type_folder)
    for image in folder_data:
        #opening image
        image_path = type_folder + "\\" + image
        image = cv2.imread(image_path)
        image_new = cv2.resize(image, (32,32))
        image_sized = image_new.astype("float32")/255
        X.append(np.array(image_sized))
        Y.append(image_type)

        
        image_flipped_hor = cv2.flip(image_new, 1)
        image_sized = image_flipped_hor.astype("float32")/255
        X.append(np.array(image_sized))
        Y.append(image_type)
        
        image_flipped_vert = cv2.flip(image_new, 1)
        image_sized = image_flipped_vert.astype("float32")/255
        X.append(np.array(image_sized))
        Y.append(image_type)
        
Y = np.array(Y)
X = np.array(X)

enc = OneHotEncoder(sparse = False)
Y = enc.fit_transform(Y.reshape((-1,1)))

r = np.arange(X.shape[0])
np.random.seed(69)
np.random.shuffle(r)
X = X[r]
Y = Y[r]


train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size = 0.33)

# %%
alexNetModel = Sequential([
    Conv2D(filters=96,kernel_size=(3,3),strides=(4,4),input_shape=(32,32,3), activation='relu'),
    MaxPool2D(pool_size=(2,2),strides=(2,2))   ,
    Conv2D(256,(5,5),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2),strides=(2,2)),
    Conv2D(384,(3,3),padding='same',activation='relu'),
    Conv2D(384,(3,3),padding='same',activation='relu'),
    Conv2D(256,(3,3),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2),strides=(2,2)),
    Flatten(),
    Dense(4096, activation='relu'),
    Dropout(0.4),
    Dense(4096, activation='relu'),
    Dropout(0.4),
    Dense(8,activation='softmax')
])

alexNetModel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = alexNetModel.fit(train_X, train_Y, epochs=40,  validation_data=(test_X, test_Y))
# Out:
# Epoch 1/40
# 434/434 [==============================] - 49s 112ms/step - loss: 1.4421 - accuracy: 0.4087 - val_loss: 0.9441 - val_accuracy: 0.6213
# Epoch 2/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.7412 - accuracy: 0.7086 - val_loss: 0.4923 - val_accuracy: 0.8141
# Epoch 3/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.4328 - accuracy: 0.8331 - val_loss: 0.4261 - val_accuracy: 0.8154
# Epoch 4/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.3242 - accuracy: 0.8765 - val_loss: 0.3713 - val_accuracy: 0.8581
# Epoch 5/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.2873 - accuracy: 0.8933 - val_loss: 0.4683 - val_accuracy: 0.8457
# Epoch 6/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.2556 - accuracy: 0.9070 - val_loss: 0.3061 - val_accuracy: 0.8931
# Epoch 7/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.2125 - accuracy: 0.9261 - val_loss: 0.3141 - val_accuracy: 0.8968
# Epoch 8/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.1830 - accuracy: 0.9401 - val_loss: 0.2801 - val_accuracy: 0.9067
# Epoch 9/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.1670 - accuracy: 0.9441 - val_loss: 0.3044 - val_accuracy: 0.9111
# Epoch 10/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.1252 - accuracy: 0.9572 - val_loss: 0.3034 - val_accuracy: 0.9182
# Epoch 11/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.1177 - accuracy: 0.9605 - val_loss: 0.3325 - val_accuracy: 0.9160
# Epoch 12/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.1342 - accuracy: 0.9616 - val_loss: 0.2510 - val_accuracy: 0.9303
# Epoch 13/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.1077 - accuracy: 0.9658 - val_loss: 0.2491 - val_accuracy: 0.9325
# Epoch 14/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.0906 - accuracy: 0.9735 - val_loss: 0.3226 - val_accuracy: 0.9277
# Epoch 15/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.0820 - accuracy: 0.9759 - val_loss: 0.3811 - val_accuracy: 0.9196
# Epoch 16/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0903 - accuracy: 0.9747 - val_loss: 0.3375 - val_accuracy: 0.9111
# Epoch 17/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0798 - accuracy: 0.9757 - val_loss: 0.3862 - val_accuracy: 0.9013
# Epoch 18/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.0663 - accuracy: 0.9807 - val_loss: 0.4580 - val_accuracy: 0.9028
# Epoch 19/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.0959 - accuracy: 0.9738 - val_loss: 0.3222 - val_accuracy: 0.9316
# Epoch 20/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0564 - accuracy: 0.9841 - val_loss: 0.3049 - val_accuracy: 0.9321
# Epoch 21/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0955 - accuracy: 0.9750 - val_loss: 0.4714 - val_accuracy: 0.9022
# Epoch 22/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.1000 - accuracy: 0.9729 - val_loss: 1.4127 - val_accuracy: 0.8864
# Epoch 23/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.0512 - accuracy: 0.9843 - val_loss: 0.3714 - val_accuracy: 0.9290
# Epoch 24/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0248 - accuracy: 0.9923 - val_loss: 0.3557 - val_accuracy: 0.9366
# Epoch 25/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0366 - accuracy: 0.9890 - val_loss: 0.4031 - val_accuracy: 0.9384
# Epoch 26/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0470 - accuracy: 0.9857 - val_loss: 0.4244 - val_accuracy: 0.9401
# Epoch 27/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.1342 - accuracy: 0.9642 - val_loss: 0.3849 - val_accuracy: 0.9252
# Epoch 28/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.0411 - accuracy: 0.9899 - val_loss: 0.4575 - val_accuracy: 0.9189
# Epoch 29/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.1462 - accuracy: 0.9722 - val_loss: 0.3120 - val_accuracy: 0.9372
# Epoch 30/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0257 - accuracy: 0.9936 - val_loss: 0.3400 - val_accuracy: 0.9351
# Epoch 31/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0604 - accuracy: 0.9855 - val_loss: 0.3837 - val_accuracy: 0.9240
# Epoch 32/40
# 434/434 [==============================] - 48s 110ms/step - loss: 0.0292 - accuracy: 0.9916 - val_loss: 0.4339 - val_accuracy: 0.9360
# Epoch 33/40
# 434/434 [==============================] - 50s 114ms/step - loss: 0.0349 - accuracy: 0.9913 - val_loss: 0.4333 - val_accuracy: 0.9404
# Epoch 34/40
# 434/434 [==============================] - 49s 112ms/step - loss: 0.0340 - accuracy: 0.9907 - val_loss: 0.3560 - val_accuracy: 0.9401
# Epoch 35/40
# 434/434 [==============================] - 49s 112ms/step - loss: 0.0184 - accuracy: 0.9957 - val_loss: 0.4241 - val_accuracy: 0.9330
# Epoch 36/40
# 434/434 [==============================] - 49s 112ms/step - loss: 0.1187 - accuracy: 0.9695 - val_loss: 0.3213 - val_accuracy: 0.9321
# Epoch 37/40
# 434/434 [==============================] - 49s 112ms/step - loss: 0.0473 - accuracy: 0.9883 - val_loss: 0.4146 - val_accuracy: 0.9403
# Epoch 38/40
# 434/434 [==============================] - 49s 112ms/step - loss: 0.0521 - accuracy: 0.9883 - val_loss: 0.2758 - val_accuracy: 0.9349
# Epoch 39/40
# 434/434 [==============================] - 49s 112ms/step - loss: 0.0573 - accuracy: 0.9844 - val_loss: 0.4118 - val_accuracy: 0.9308
# Epoch 40/40
# 434/434 [==============================] - 48s 111ms/step - loss: 0.0439 - accuracy: 0.9900 - val_loss: 0.3234 - val_accuracy: 0.9385

# %%
print("Max Train Acccraucy: ", max(history.history['accuracy']))
print("Max Test Acccraucy: ", max(history.history['val_accuracy']))
# Out:
# Max Train Acccraucy:  0.995672881603241
# Max Test Acccraucy:  0.9404186606407166

# %%
plt.plot(history.history['accuracy'], label='acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
